# %% [markdown]
# ##### Waheeb Algabri

# %% [markdown]
# ### **Introduction:**
#
# In this assignment 6, you'll dive into data exploration using Python and pandas. You'll choose four datasets, load them into your preferred Python environment, and analyze them. This assignment guides you through key data handling techniques, from loading data to extracting insights. For those seeking a challenge, bonus tasks are available, including data cleaning and header manipulation. Get ready to become a proficient data explorer by the end of this assignment!

# %%
#Impoprting the required libraries
import pandas as pd

# %% [markdown]
# **Q1. Load your dataset into python using the pandas library and save data into a dataframe named dfi (where i is one of your datasets, for a total of 4)**

# %%
# Importing from the desired github repo
df1 = pd.read_csv("https://raw.githubusercontent.com/data602sps/datasetspractice/main/GOOG.csv")
df2 = pd.read_csv("https://raw.githubusercontent.com/data602sps/datasetspractice/main/weather.csv")

# Importing from the given links:
df3 = pd.read_csv("https://raw.githubusercontent.com/waheeb123/Stock-Data_USA/main/daily_adjusted_AMZN.csv")
df4 = pd.read_csv("https://raw.githubusercontent.com/waheeb123/SPRING2023TIDYVERSE/main/Waheeb_Algabri_files/master.csv")

# %% [markdown]
# **Q2. Preview your data by calling your dataframe’s name. How many columns and rows do you see?**

# %%
df1
# Out:
#             Date         Open         High          Low        Close  \
# 0     2014-06-24   562.099304   569.514526   557.942139   561.532410
# 1     2014-06-25   562.168884   576.788513   562.129089   575.485657
# 2     2014-06-26   577.822815   579.264893   568.722839   572.850159
# 3     2014-06-27   574.023682   576.698975   570.662170   574.083374
# 4     2014-06-30   575.495605   576.400635   571.606995   572.134094
# ...          ...          ...          ...          ...          ...
# 1253  2019-06-17  1086.280029  1099.180054  1086.280029  1092.500000
# 1254  2019-06-18  1109.689941  1116.390015  1098.989990  1103.599976
# 1255  2019-06-19  1105.599976  1107.000000  1093.479980  1102.329956
# 1256  2019-06-20  1119.989990  1120.119995  1104.739990  1111.420044
# 1257  2019-06-21  1109.239990  1124.109985  1108.079956  1121.880005
#
#         Adj Close   Volume
# 0      561.532410  2213200
# 1      575.485657  1974700
# 2      572.850159  1746700
# ...

# %% [markdown]
# df1 has 51 rows and 3 columns

# %%
df2
# Out:
#       Unnamed: 0 origin  year  month   day  hour   temp   dewp  humid  \
# 0              1    EWR  2013    1.0   1.0   0.0  37.04  21.92  53.97
# 1              2    EWR  2013    1.0   1.0   1.0  37.04  21.92  53.97
# 2              3    EWR  2013    1.0   1.0   2.0  37.94  21.92  52.09
# 3              4    EWR  2013    1.0   1.0   3.0  37.94  23.00  54.51
# 4              5    EWR  2013    1.0   1.0   4.0  37.94  24.08  57.04
# ...          ...    ...   ...    ...   ...   ...    ...    ...    ...
# 8714        8715    JFK  2013    9.0   2.0  20.0  75.20  73.40  94.14
# 8715        8716    JFK  2013   10.0  23.0  10.0  48.92  39.02  68.51
# 8716        8717    JFK  2013   10.0  23.0  11.0  48.92  39.02  68.51
# 8717        8718    JFK  2013   12.0  17.0   5.0  26.96  10.94  50.34
# 8718        8719    LGA  2013    8.0  22.0  22.0  75.92  66.92  73.68
#
#       wind_dir  wind_speed  wind_gust  precip  pressure  visib
# 0        230.0    10.35702  11.918651     0.0    1013.9   10.0
# ...

# %% [markdown]
# df2 has 458 rows and 9 columns

# %%
df3
# Out:
#        timestamp     open       high        low    close  adjusted_close  \
# 0     2020-09-01  3489.58  3513.8700  3467.0000  3499.12         3499.12
# 1     2020-08-31  3408.99  3495.0000  3405.0000  3450.96         3450.96
# 2     2020-08-28  3423.00  3433.3699  3386.5000  3401.80         3401.80
# 3     2020-08-27  3450.05  3453.0000  3378.0000  3400.00         3400.00
# 4     2020-08-26  3351.11  3451.7387  3344.5675  3441.85         3441.85
# ...          ...      ...        ...        ...      ...             ...
# 5195  2000-01-07    67.00    70.5000    66.1900    69.56           69.56
# 5196  2000-01-06    71.31    72.6900    64.0000    65.56           65.56
# 5197  2000-01-05    70.75    75.1300    69.6300    71.75           71.75
# 5198  2000-01-04    85.38    91.5000    81.7500    81.94           81.94
# 5199  2000-01-03    81.50    89.5600    80.0000    89.38           89.38
#
#         volume  dividend_amount  split_coefficient
# ...

# %% [markdown]
# df3 has 7258 rows and 12 columns

# %%
df4
# Out:
#                         country  year     sex          age  suicides_no  \
# 0                       Albania  1987    male  15-24 years         21.0
# 1                       Albania  1987    male  35-54 years         16.0
# 2                       Albania  1987  female  15-24 years         14.0
# 3                       Albania  1987    male    75+ years          1.0
# 4                       Albania  1987    male  25-34 years          9.0
# ...                         ...   ...     ...          ...          ...
# 31751                   Ukraine  2017  female    75+ years        256.0
# 31752            United Kingdom  2017  female    75+ years        104.0
# 31753  United States of America  2017  female    75+ years        501.0
# 31754                   Uruguay  2017  female    75+ years         14.0
# 31755                Uzbekistan  2017  female    75+ years          3.0
#
#        population  suicides/100k pop                  country-year  \
# ...

# %% [markdown]
# df4 has 5110 rows and 12 columns

# %% [markdown]
# **Q3. Examine the shape of your data using the .shape command and the data types of your columns using .dtypes.**

# %%
df1.shape
# Out:
# (1258, 7)

# %%
df1.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df2.shape
# Out:
# (8719, 15)

# %%
df2.dtypes
# Out:
# Unnamed: 0      int64
# origin         object
# year            int64
# month         float64
# day           float64
# hour          float64
# temp          float64
# dewp          float64
# humid         float64
# wind_dir      float64
# wind_speed    float64
# wind_gust     float64
# precip        float64
# pressure      float64
# visib         float64
# dtype: object

# %%
df3.shape
# Out:
# (5200, 9)

# %%
df3.dtypes
# Out:
# timestamp             object
# open                 float64
# high                 float64
# low                  float64
# close                float64
# adjusted_close       float64
# volume                 int64
# dividend_amount      float64
# split_coefficient    float64
# dtype: object

# %%
df4.shape
# Out:
# (31756, 12)

# %%
df4.dtypes
# Out:
# country                object
# year                    int64
# sex                    object
# age                    object
# suicides_no           float64
# population              int64
# suicides/100k pop     float64
# country-year           object
# HDI for year          float64
#  gdp_for_year ($)      object
# gdp_per_capita ($)    float64
# generation             object
# dtype: object

# %% [markdown]
# **Q4. Use .describe() on your data. What do you notice about your data? What does this command return?**

# %%
df4.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  31756.000000  30556.000000  3.175600e+04       31756.000000
# mean    2003.395390    237.136242  7.217454e+06          11.716668
# std        9.760604    867.956107  5.799323e+07          21.590926
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1996.000000      3.000000  1.288210e+05           0.370000
# 50%     2004.000000     25.000000  5.468325e+05           4.285000
# 75%     2011.000000    132.000000  2.908763e+06          14.560000
# max     2020.000000  22338.000000  1.411100e+09         515.092734
#
#        HDI for year  gdp_per_capita ($)
# count  12300.000000        31756.000000
# mean       0.793666        17588.954606
# std        0.097480        19464.861140
# min        0.377790          251.000000
# 25%        0.727000         3765.000000
# 50%        0.800457        10062.000000
# 75%        0.874000        25622.000000
# ...

# %% [markdown]
# The **.describe()** method computes and displays summary statistics for a Python dataframe as we can see that in the above code chunk. Let's try it on other dataframes too.

# %%
df3.describe()
# Out:
#               open         high          low        close  adjusted_close  \
# count  5200.000000  5200.000000  5200.000000  5200.000000     5200.000000
# mean    428.271603   433.019992   423.146543   428.358279      428.358279
# std     634.376538   641.288653   626.933748   634.562686      634.562686
# min       5.910000     6.100000     5.510000     5.970000        5.970000
# 25%      41.297500    42.175000    40.507500    41.375000       41.375000
# 50%     129.600050   131.085000   127.680000   129.655000      129.655000
# 75%     440.317500   445.360000   436.645000   440.285000      440.285000
# max    3489.580000  3513.870000  3467.000000  3499.120000     3499.120000
#
#              volume  dividend_amount  split_coefficient
# count  5.200000e+03           5200.0             5200.0
# mean   6.491234e+06              0.0                1.0
# std    5.097986e+06              0.0                0.0
# min    8.813370e+05              0.0                1.0
# ...

# %%
df2.describe()
# Out:
#         Unnamed: 0    year        month          day         hour  \
# count  8719.000000  8719.0  8718.000000  8718.000000  8718.000000
# mean   4360.000000  2013.0     6.506538    15.679628    11.515715
# std    2517.102832     0.0     3.439961     8.768250     6.916846
# min       1.000000  2013.0     1.000000     1.000000     0.000000
# 25%    2180.500000  2013.0     4.000000     8.000000     6.000000
# 50%    4360.000000  2013.0     7.000000    16.000000    12.000000
# 75%    6539.500000  2013.0     9.000000    23.000000    18.000000
# max    8719.000000  2013.0    12.000000    31.000000    23.000000
#
#               temp         dewp        humid     wind_dir   wind_speed  \
# count  8718.000000  8718.000000  8718.000000  8486.000000  8718.000000
# mean     55.484942    41.794184    62.863333   193.194674     9.335732
# std      18.345817    19.619776    19.572699   110.541333    12.328261
# min      10.940000    -9.040000    13.950000     0.000000     0.000000
# ...

# %%
df1.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    842.065785   849.196733   834.607101   842.175733   842.175733
# std     224.688021   227.042283   222.565409   224.969453   224.969453
# min     491.942810   493.261566   484.891632   489.854309   489.854309
# 25%     645.425003   650.681763   637.150024   643.905029   643.905029
# 50%     795.364990   801.023010   790.855011   795.359985   795.359985
# 75%    1051.584992  1064.093719  1040.893494  1052.059967  1052.059967
# max    1274.000000  1289.270020  1266.295044  1287.579956  1287.579956
#
#              Volume
# count  1.258000e+03
# mean   1.750196e+06
# std    8.586929e+05
# min    5.272000e+05
# 25%    1.243325e+06
# 50%    1.531050e+06
# 75%    1.995025e+06
# max    1.116490e+07

# %% [markdown]
# **Q5. Use the .head() and .tail() command - what does this do?**

# %%
df1.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 1  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 2  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 3  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 4  2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
#
#     Volume
# 0  2213200
# 1  1974700
# 2  1746700
# 3  2243000
# 4  1317300

# %% [markdown]
# **.head()** method returns or displays the first 5 rows of dataframe. We can also specify the number of rows that we want to display inside the paranthesis. Lets display the first 10 row of the dataframe with head method

# %%
df1.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 1  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 2  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 3  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 4  2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
# 5  2014-07-01  575.157471  581.204224  573.496582  579.483704  579.483704
# 6  2014-07-02  580.159973  582.238525  577.216125  579.150513  579.150513
# 7  2014-07-03  580.159973  581.810913  577.743286  581.532410  581.532410
# 8  2014-07-07  580.567749  583.223145  576.420532  579.065979  579.065979
# 9  2014-07-08  574.501099  576.358887  563.039124  567.967041  567.967041
#
#     Volume
# 0  2213200
# 1  1974700
# 2  1746700
# 3  2243000
# 4  1317300
# 5  1451900
# 6  1059200
# 7   716100
# 8  1067500
# 9  1914700

# %%
df1.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 1253  2019-06-17  1086.280029  1099.180054  1086.280029  1092.500000
# 1254  2019-06-18  1109.689941  1116.390015  1098.989990  1103.599976
# 1255  2019-06-19  1105.599976  1107.000000  1093.479980  1102.329956
# 1256  2019-06-20  1119.989990  1120.119995  1104.739990  1111.420044
# 1257  2019-06-21  1109.239990  1124.109985  1108.079956  1121.880005
#
#         Adj Close   Volume
# 1253  1092.500000   941600
# 1254  1103.599976  1386700
# 1255  1102.329956  1338800
# 1256  1111.420044  1262000
# 1257  1121.880005  1930100

# %% [markdown]
# **.tail()** method returns or displays the last five rows of the dataframe and just like .head method we can also specify the number of rows insde the paranthesis that we want to display.
#
# Lets apply it to other dataframes:

# %%
df2.head()
# Out:
#    Unnamed: 0 origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0           1    EWR  2013    1.0  1.0   0.0  37.04  21.92  53.97     230.0
# 1           2    EWR  2013    1.0  1.0   1.0  37.04  21.92  53.97     230.0
# 2           3    EWR  2013    1.0  1.0   2.0  37.94  21.92  52.09     230.0
# 3           4    EWR  2013    1.0  1.0   3.0  37.94  23.00  54.51     230.0
# 4           5    EWR  2013    1.0  1.0   4.0  37.94  24.08  57.04     240.0
#
#    wind_speed  wind_gust  precip  pressure  visib
# 0    10.35702  11.918651     0.0    1013.9   10.0
# 1    13.80936  15.891535     0.0    1013.0   10.0
# 2    12.65858  14.567241     0.0    1012.6   10.0
# 3    13.80936  15.891535     0.0    1012.7   10.0
# 4    14.96014  17.215830     0.0    1012.8   10.0

# %%
df2.tail()
# Out:
#       Unnamed: 0 origin  year  month   day  hour   temp   dewp  humid  \
# 8714        8715    JFK  2013    9.0   2.0  20.0  75.20  73.40  94.14
# 8715        8716    JFK  2013   10.0  23.0  10.0  48.92  39.02  68.51
# 8716        8717    JFK  2013   10.0  23.0  11.0  48.92  39.02  68.51
# 8717        8718    JFK  2013   12.0  17.0   5.0  26.96  10.94  50.34
# 8718        8719    LGA  2013    8.0  22.0  22.0  75.92  66.92  73.68
#
#       wind_dir  wind_speed  wind_gust  precip  pressure  visib
# 8714     200.0     4.60312   5.297178     0.0       NaN    4.0
# 8715      60.0     4.60312   5.297178     0.0    1008.1   10.0
# 8716      40.0     4.60312   5.297178     0.0    1008.5   10.0
# 8717      40.0     4.60312   5.297178     0.0    1023.9   10.0
# 8718     210.0     8.05546   9.270062     0.0    1011.9   10.0

# %%
df3.head()
# Out:
#     timestamp     open       high        low    close  adjusted_close  \
# 0  2020-09-01  3489.58  3513.8700  3467.0000  3499.12         3499.12
# 1  2020-08-31  3408.99  3495.0000  3405.0000  3450.96         3450.96
# 2  2020-08-28  3423.00  3433.3699  3386.5000  3401.80         3401.80
# 3  2020-08-27  3450.05  3453.0000  3378.0000  3400.00         3400.00
# 4  2020-08-26  3351.11  3451.7387  3344.5675  3441.85         3441.85
#
#     volume  dividend_amount  split_coefficient
# 0  3476407              0.0                1.0
# 1  4185885              0.0                1.0
# 2  2896978              0.0                1.0
# 3  4264795              0.0                1.0
# 4  6508743              0.0                1.0

# %%
df3.tail()
# Out:
#        timestamp   open   high    low  close  adjusted_close    volume  \
# 5195  2000-01-07  67.00  70.50  66.19  69.56           69.56  10505400
# 5196  2000-01-06  71.31  72.69  64.00  65.56           65.56  18752000
# 5197  2000-01-05  70.75  75.13  69.63  71.75           71.75  38457400
# 5198  2000-01-04  85.38  91.50  81.75  81.94           81.94  17487400
# 5199  2000-01-03  81.50  89.56  80.00  89.38           89.38  16117600
#
#       dividend_amount  split_coefficient
# 5195              0.0                1.0
# 5196              0.0                1.0
# 5197              0.0                1.0
# 5198              0.0                1.0
# 5199              0.0                1.0

# %%
df4.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years         21.0      312900
# 1  Albania  1987    male  35-54 years         16.0      308000
# 2  Albania  1987  female  15-24 years         14.0      289700
# 3  Albania  1987    male    75+ years          1.0       21800
# 4  Albania  1987    male  25-34 years          9.0      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN     2,15,66,24,900
# 1               5.19  Albania1987           NaN     2,15,66,24,900
# 2               4.83  Albania1987           NaN     2,15,66,24,900
# 3               4.59  Albania1987           NaN     2,15,66,24,900
# 4               3.28  Albania1987           NaN     2,15,66,24,900
#
#    gdp_per_capita ($)       generation
# 0               796.0     Generation X
# 1               796.0           Silent
# 2               796.0     Generation X
# ...

# %%
df4.tail()
# Out:
#                         country  year     sex        age  suicides_no  \
# 31751                   Ukraine  2017  female  75+ years        256.0
# 31752            United Kingdom  2017  female  75+ years        104.0
# 31753  United States of America  2017  female  75+ years        501.0
# 31754                   Uruguay  2017  female  75+ years         14.0
# 31755                Uzbekistan  2017  female  75+ years          3.0
#
#        population  suicides/100k pop                  country-year  \
# 31751    44831135           0.571032                   Ukraine2017
# 31752    66058859           0.157435            United Kingdom2017
# 31753   325122128           0.154096  United States of America2017
# 31754     3422200           0.409094                   Uruguay2017
# 31755    32388600           0.009263                Uzbekistan2017
#
#        HDI for year  gdp_for_year ($)   gdp_per_capita ($)       generation
# ...

# %% [markdown]
# ### **Extra Credit (3 pts)**
#
# > 1. Choose one of your datasets and remove the header information. (Can delete the row in excel, etc..)
# > 2. Import the data into your environment using pandas. Display the .head() of your data showing no header information.
# > 3. Using pandas, update the dataset to include the header information. Display the updated data using .head().

# %%
df_nohead=pd.read_csv("https://raw.githubusercontent.com/waheeb123/SPRING2023TIDYVERSE/main/Waheeb_Algabri_files/master.csv")
df_nohead.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years         21.0      312900
# 1  Albania  1987    male  35-54 years         16.0      308000
# 2  Albania  1987  female  15-24 years         14.0      289700
# 3  Albania  1987    male    75+ years          1.0       21800
# 4  Albania  1987    male  25-34 years          9.0      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN     2,15,66,24,900
# 1               5.19  Albania1987           NaN     2,15,66,24,900
# 2               4.83  Albania1987           NaN     2,15,66,24,900
# 3               4.59  Albania1987           NaN     2,15,66,24,900
# 4               3.28  Albania1987           NaN     2,15,66,24,900
#
#    gdp_per_capita ($)       generation
# 0               796.0     Generation X
# 1               796.0           Silent
# 2               796.0     Generation X
# ...

# %%
df_head = pd.read_csv("https://raw.githubusercontent.com/waheeb123/SPRING2023TIDYVERSE/main/Waheeb_Algabri_files/master.csv", names=["id",	"gender",	"age",	"hypertension",	"heart_disease",	"ever_married",	"work_type",	"Residence_type",	"avg_glucose_level",	"bmi",	"smoking_status",	"stroke"])
df_head.head()
# Out:
#         id gender     age hypertension heart_disease ever_married  \
# 0  country   year     sex          age   suicides_no   population
# 1  Albania   1987    male  15-24 years            21       312900
# 2  Albania   1987    male  35-54 years            16       308000
# 3  Albania   1987  female  15-24 years            14       289700
# 4  Albania   1987    male    75+ years             1        21800
#
#            work_type Residence_type avg_glucose_level                 bmi  \
# 0  suicides/100k pop   country-year      HDI for year   gdp_for_year ($)
# 1               6.71    Albania1987               NaN      2,15,66,24,900
# 2               5.19    Albania1987               NaN      2,15,66,24,900
# 3               4.83    Albania1987               NaN      2,15,66,24,900
# 4               4.59    Albania1987               NaN      2,15,66,24,900
#
#        smoking_status           stroke
# 0  gdp_per_capita ($)       generation
# 1                 796     Generation X
# ...

# %% [markdown]
# ### **Extra Credit (3 pts)**
#
# > 1. Import a “dirty” dataset from the internet into your environment. (Missing values, improper coding of columns, etc.)
# > 2. Clean or “tidy” the data when loading into python using pandas.

# %% [markdown]
# Read the data from mysql using python

# %%
# Import the required libraries
from IPython.display import display

# !pip install pymysql

# Import the required libraries
import pandas as pd
from sqlalchemy import create_engine

# Replace these placeholders with your database credentials
host = "localhost"
username = "root"
password = "Alex9297248844"
dbname = "titanic_dirty"

# Create a database connection
engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}/{dbname}')

# %%
table_name = 'df5'

# SQL query to select all data from the table
query = f'SELECT * FROM {table_name}'

# Execute the SQL query and read the result into a DataFrame
df5 = pd.read_sql(query, engine)

# %%
# Print the DataFrame
display(df5)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 226         1296         0       1
# 227         1298         0       2
# 228         1299         0       1
# 229         1303         1       1
# 230         1304         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
# Check dimentions
df5.shape
# Out:
# (231, 12)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  231 non-null    int64
#  1   Survived     231 non-null    int64
#  2   Pclass       231 non-null    int64
#  3   Name         231 non-null    object
#  4   Sex          231 non-null    object
#  5   Age          231 non-null    float64
#  6   SibSp        231 non-null    int64
#  7   Parch        231 non-null    int64
#  8   Ticket       231 non-null    int64
#  9   Fare         231 non-null    float64
#  10  Cabin        231 non-null    object
#  11  Embarked     231 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 21.8+ KB

# %%
# Check the first 7 rows
df5.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# 6                          Connolly, Miss. Kate  female  30.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292              Q
# ...

# %%
df5.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   231.000000  231.000000  231.000000  231.000000  231.000000
# mean   1102.207792    0.363636    2.190476   30.002857    0.454545
# std     123.498460    0.482090    0.853685   13.622623    0.778160
# min     892.000000    0.000000    1.000000    0.330000    0.000000
# 25%     992.500000    0.000000    1.000000   21.000000    0.000000
# 50%    1106.000000    0.000000    2.000000   27.000000    0.000000
# 75%    1211.000000    1.000000    3.000000   38.000000    1.000000
# max    1304.000000    1.000000    3.000000   76.000000    4.000000
#
#             Parch        Ticket        Fare
# count  231.000000  2.310000e+02  231.000000
# mean     0.337662  2.320951e+05   34.002906
# std      0.721298  4.084430e+05   46.641425
# min      0.000000  6.800000e+02    0.000000
# 25%      0.000000  2.058900e+04    7.895800
# 50%      0.000000  2.284140e+05   13.500000
# 75%      0.000000  3.470710e+05   31.943750
# ...

# %% [markdown]
# Notice that non numeric columns are dropped from the stastical summary provided so we can get summary of the categorical variables by passing only those columns to describe():

# %%
categorical = df5.dtypes[df5.dtypes == "object"].index
print(categorical)
df5[categorical].describe()
# Out:
# Index(['Name', 'Sex', 'Cabin', 'Embarked'], dtype='object')
#                     Name   Sex Cabin Embarked
# count                231   231   231      231
# unique               231     2    46        3
# top     Kelly, Mr. James  male              S
# freq                   1   147   174      162

# %%
# Remove PassengerId

del df5["PassengerId"]

# %%
# First 15 sorted names
sorted(df5["Name"])[0:15]
# Out:
# ['Abelseth, Miss. Karen Marie',
#  'Abelseth, Mr. Olaus Jorgensen',
#  'Abrahim, Mrs. Joseph (Sophie Halaut Easu)',
#  'Aks, Master. Philip Frank',
#  'Aldworth, Mr. Charles Augustus',
#  'Allison, Mr. Hudson Joshua Creighton',
#  'Andersson, Miss. Ida Augusta Margareta',
#  'Andersson, Mr. Johan Samuel',
#  'Angheloff, Mr. Minko',
#  'Angle, Mr. William A',
#  'Aronsson, Mr. Ernst Axel Algot',
#  'Ashby, Mr. John',
#  'Asplund, Master. Carl Edgar',
#  'Asplund, Master. Filip Oscar',
#  'Asplund, Mr. Carl Oscar Vilhelm Gustafsson']

# %%
new_Pclass = pd.Categorical (df5["Pclass"],
ordered=True)
new_Pclass = new_Pclass. rename_categories (["Class1", "Class2", "Class3"])
new_Pclass.describe ()
# Out:
#             counts     freqs
# categories
# Class1          66  0.285714
# Class2          55  0.238095
# Class3         110  0.476190

# %%
df5["Pclass"]= new_Pclass

# %%
# Check unique Cabin

df5["Cabin"].unique()
# Out:
# array(['', 'B45', 'B36', 'A21', 'C78', 'D19', 'D15', 'C31', 'C23 C25 C27',
#        'F G63', 'C53', 'C130', 'C132', 'C101', 'C46', 'C116', 'F', 'C6',
#        'C28', 'C51', 'C54', 'D22', 'F4', 'D30', 'E34', 'B11', 'C80',
#        'D37', 'D21', 'C89', 'A34', 'B26', 'C22 C26', 'B69', 'F E57', 'F2',
#        'C106', 'E60', 'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24',
#        'B41', 'C7', 'D40'], dtype=object)

# %%
df5.hist(column="Age", figsize=(9, 6), bins=20)
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)
